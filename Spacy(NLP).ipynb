# %%
import spacy

nlp = spacy.load("en_core_web_sm")
doc = nlp("Apple is looking at buying U.K. startup for $1 billion")
for token in doc:
    print(token.text, token.pos_, token.dep_)
# Out:
# Apple PROPN nsubj
# is AUX aux
# looking VERB ROOT
# at ADP prep
# buying VERB pcomp
# U.K. PROPN compound
# startup NOUN dobj
# for ADP prep
# $ SYM quantmod
# 1 NUM compound
# billion NUM pobj

# %%
import pandas as pd

# %%
# df = pd.read_csv('C:/Users/Administrator/Desktop/JD.txt', header=None)
# df_csv = pd.read_csv('C:/Users/Administrator/Desktop/JD.txt',sep="\n",header=None,engine='python')
df_csv = open('C:/Users/Administrator/Desktop/JD.txt', encoding="utf8").read()

# %%
nlp = spacy.load("en_core_web_sm")

# %%
doc = nlp(df_csv)

# %%
token_list = [token for token in doc]

# %%
token_list
# Out:
# [Data,
#  Scientist,
#  ,
#  HomeInternational,
#  Saudi,
#  Arabia,
#  Eastern,
#  Province,
#  KhobarJobs,
#  ,
#  Date,
#  :,
#  Monday,
#  ,,
#  March,
#  01,
#  ,,
#  2021,
#  ,
#  Category,
#  :,
#  Jobs,
#  ,
#  Region,
#  Khobar,
#  ,
#  Posting,
#  ID,
#  :,
#  47603327,
#  ,
#  Job,
#  Duties,
#  /,
#  Responsibilities,
#  ,
#  •,
#  Ingest,
#  ,,
#  organize,
#  ,,
#  and,
#  analyze,
#  data,
#  from,
#  various,
#  sources,
#  (,
#  e.g.,
#  CSV,
#  ,,
#  relational,
#  database,
#  ),
#  ,
#  •,
#  Scope,
#  unstructured,
#  problems,
#  or,
#  messy,
#  data,
#  for,
#  tractable,
#  insights,
#  ,
#  •,
#  Identify,
#  candidate,
#  statistical,
#  or,
#  machine,
#  learning,
#  solutions,
#  and,
#  test,
#  their,
#  efficacy,
#  ,
#  •,
#  Communicate,
#  technical,
#  work,
#  and,
#  findings,
#  both,
#  verbally,
#  and,
#  through,
#  written,
#  reports,
#  and,
#  visualizations,
#  ,
#  •,
#  Work,
#  in,
#  a,
#  collaborative,
#  environment,
#  to,
#  brainstorm,
#  ,,
#  design,
#  ,,
#  implement,
#  and,
#  deliver,
#  solutions,
#  to,
#  challenging,
#  problems,
#  ,
#  Qualifications,
#  and,
#  Skills,
#  ,
#  •,
#  3,
#  +,
#  years,
#  of,
#  relevant,
#  data,
#  science,
#  work,
#  experience,
#  ,
#  •,
#  2,
#  +,
#  years,
#  of,
#  relevant,
#  oil,
#  and,
#  gas,
#  industry,
#  experience,
#  ,
#  •,
#  Excellent,
#  understanding,
#  of,
#  statistical,
#  or,
#  machine,
#  learning,
#  techniques,
#  ,,
#  such,
#  as,
#  clustering,
#  ,,
#  regression,
#  ,,
#  time,
#  series,
#  forecasting,
#  ,,
#  tree,
#  -,
#  based,
#  methods,
#  ,,
#  sampling,
#  methods,
#  ,
#  •,
#  Demonstrated,
#  ability,
#  using,
#  scientific,
#  computing,
#  libraries,
#  ,,
#  such,
#  as,
#  NumPy,
#  ,,
#  Pandas,
#  ,,
#  SciPy,
#  ,,
#  Scikit,
#  -,
#  learn,
#  ,,
#  Matplotlib,
#  ,,
#  and,
#  Plotly,
#  ,
#  •,
#  Programming,
#  proficiency,
#  in,
#  Python,
#  ,
#  Preferred,
#  Requirements,
#  ,
#  •,
#  Ph.D.,
#  or,
#  Master,
#  ’s,
#  ,
#  •,
#  Petroleum,
#  Engineering,
#  or,
#  Geoscience,
#  background,
#  ,
#  •,
#  Strong,
#  statistical,
#  knowledge,
#  and,
#  experience,
#  with,
#  hypothesis,
#  testing,
#  ,
#  •,
#  Fluency,
#  with,
#  machine,
#  learning,
#  algorithms,
#  ,,
#  such,
#  as,
#  CNN,
#  ,,
#  RNN,
#  ,,
#  reinforcement,
#  learning,
#  ,,
#  support,
#  vector,
#  machines,
#  ,,
#  and,
#  graph,
#  -,
#  based,
#  models,
#  ,
#  •,
#  Experience,
#  with,
#  TensorFlow,
#  ,,
#  Keras,
#  ,,
#  or,
#  PyTorch,
#  ,
#  •,
#  Experience,
#  with,
#  version,
#  control,
#  systems,
#  (,
#  e.g.,
#  Git,
#  flow,
#  ),
#  ,
#  •,
#  Strong,
#  oral,
#  and,
#  verbal,
#  communication,
#  skills,
#  ,
#  •,
#  Research,
#  experience,
#  with,
#  high,
#  impact,
#  publications,
#  ,
#  •,
#  Experience,
#  working,
#  with,
#  cross,
#  -,
#  functional,
#  teams,
#  and/or,
#  customer,
#  facing,
#  work,
#
#  ,
#  Please,
#  send,
#  CV,
#  with,
#  cover,
#  letter,
#  to,
#  HR@metelecom.net.sa,
#
#
#  ,
#  Dana,
#  -,
#  Farber,
#  Cancer,
#  Institute,
#  brings,
#  together,
#  world,
#  -,
#  renowned,
#  clinicians,
#  ,,
#  innovative,
#  researchers,
#  ,,
#  dedicated,
#  professionals,
#  ,,
#  and,
#  allies,
#  in,
#  the,
#  shared,
#  mission,
#  of,
#  conquering,
#  cancer,
#  and,
#  other,
#  related,
#  diseases,
#  .,
#  We,
#  combine,
#  incredibly,
#  talented,
#  people,
#  with,
#  the,
#  best,
#  technologies,
#  in,
#  a,
#  genuinely,
#  positive,
#  environment,
#  .,
#  We,
#  provide,
#  compassionate,
#  and,
#  comprehensive,
#  care,
#  to,
#  patients,
#  of,
#  all,
#  ages,
#  ;,
#  we,
#  conduct,
#  research,
#  that,
#  advances,
#  treatment,
#  ;,
#  we,
#  educate,
#  tomorrow,
#  's,
#  physician,
#  /,
#  researchers,
#  ;,
#  we,
#  reach,
#  out,
#  to,
#  underserved,
#  members,
#  of,
#  our,
#  community,
#  ;,
#  and,
#  we,
#  work,
#  with,
#  excellent,
#  partners,
#  ,,
#  including,
#  other,
#  Harvard,
#  Medical,
#  School,
#  -,
#  affiliated,
#  hospitals,
#  .,
#
#  ,
#  The,
#  Health,
#  Systems,
#  Engineer,
#  II,
#  independently,
#  leads,
#  improvement,
#  projects,
#  of,
#  moderate,
#  to,
#  complex,
#  nature,
#  for,
#  various,
#  stakeholders,
#  within,
#  the,
#  Institute,
#  .,
#  The,
#  position,
#  acts,
#  as,
#  a,
#  subject,
#  matter,
#  expert,
#  in,
#  improvement,
#  tools,
#  and,
#  techniques,
#  ,,
#  and,
#  serves,
#  as,
#  a,
#  resource,
#  to,
#  staff,
#  throughout,
#  the,
#  Institute,
#  in,
#  creating,
#  reliable,
#  ,,
#  safe,
#  and,
#  efficient,
#  processes,
#  ;,
#  Works,
#  closely,
#  with,
#  team,
#  members,
#  to,
#  ensure,
#  completion,
#  of,
#  improvement,
#  initiatives,
#  within,
#  defined,
#  budget,
#  and,
#  schedule,
#  .,
#
#  ,
#  Requirements,
#
#  ,
#  PRIMARY,
#  DUTIES,
#  AND,
#  RESPONSIBILITIES,
#  :,
#
#  ,
#  Works,
#  as,
#  a,
#  member,
#  of,
#  the,
#  Health,
#  Systems,
#  Improvement,
#  team,
#  within,
#  the,
#  Quality,
#  and,
#  Patient,
#  Safety,
#  department,
#  to,
#  plan,
#  and,
#  execute,
#  high,
#  priority,
#  initiatives,
#  with,
#  the,
#  stakeholders,
#  .,
#  Assists,
#  with,
#  business,
#  and,
#  strategy,
#  planning,
#  ,,
#  business,
#  process,
#  engineering,
#  and,
#  business,
#  transformation,
#  initiatives,
#  .,
#  ,
#  Acts,
#  as,
#  a,
#  subject,
#  matter,
#  expert,
#  in,
#  industrial,
#  and,
#  systems,
#  engineering,
#  and,
#  process,
#  improvement,
#  tools,
#  and,
#  techniques,
#  .,
#  ,
#  Independently,
#  selects,
#  appropriate,
#  methods,
#  and,
#  procedures,
#  for,
#  assigned,
#  projects,
#  .,
#  ,
#  Responsible,
#  for,
#  a,
#  portfolio,
#  of,
#  projects,
#  that,
#  consist,
#  of,
#  a,
#  broad,
#  spectrum,
#  of,
#  improvement,
#  initiatives,
#  across,
#  different,
#  departments/,
#  disciplines,
#  ensuring,
#  all,
#  project,
#  are,
#  completed,
#  within,
#  schedule,
#  and,
#  budget,
#  ..,
#  ,
#  Independently,
#  ,,
#  performs,
#  data,
#  analysis,
#  ,,
#  and,
#  develops,
#  findings,
#  and,
#  recommendations,
#  .,
#  ,
#  Creates,
#  project,
#  presentations,
#  for,
#  the,
#  steering,
#  committees,
#  ,,
#  business,
#  leaders,
#  and,
#  project,
#  sponsors,
#  .,
#  ,
#  Identifies,
#  ,,
#  translates,
#  and,
#  applies,
#  best,
#  practices,
#  within,
#  assigned,
#  projects,
#  .,
#  ,
#  Ensures,
#  communication,
#  between,
#  and,
#  among,
#  business,
#  proponents,
#  ,,
#  stakeholders,
#  and,
#  ,,
#  departmental,
#  leadership,
#  is,
#  timely,
#  and,
#  accurate,
#  .,
#  ,
#  Interacts,
#  frequently,
#  with,
#  program,
#  leaders,
#  ,,
#  staff,
#  ,,
#  and,
#  other,
#  clinicians,
#  to,
#  effectively,
#  implement,
#  improvement,
#  initiatives,
#  .,
#  ,
#  Coaches,
#  project,
#  stakeholders,
#  on,
#  planning,
#  and,
#  implementing,
#  effective,
#  workflow,
#  support,
#  and,
#  related,
#  data,
#  capture,
#  strategies,
#  .,
#  ,
#  Creates,
#  project,
#  artifacts,
#  and,
#  deliverables,
#  ,,
#  such,
#  as,
#  process,
#  flow,
#  maps,
#  ,,
#  data,
#  analysis,
#  ,,
#  models,
#  ,,
#  reports,
#  ,,
#  and,
#  develop,
#  ,,
#  organize,
#  ,,
#  and,
#  summarize,
#  materials,
#  for,
#  presentations,
#  .,
#  ,
#  Provides,
#  project,
#  support,
#  to,
#  senior,
#  members,
#  of,
#  the,
#  team,
#  .,
#  ,
#  In,
#  collaboration,
#  with,
#  the,
#  Senior,
#  Director,
#  /,
#  Manager,
#  ,,
#  develops,
#  and,
#  delivers,
#  curriculum,
#  for,
#  staff,
#  for,
#  the,
#  improvement,
#  training,
#  programs,
#  .,
#  ,
#  Performs,
#  all,
#  other,
#  related,
#  duties,
#  as,
#  required,
#  .,
#  ,
#  Qualifications,
#
#  ,
#  MINIMUM,
#  JOB,
#  QUALIFICATIONS,
#  :,
#
#  ,
#  Bachelor,
#  's,
#  degree,
#  required,
#  with,
#  formal,
#  training,
#  in,
#  Industrial,
#  and,
#  Systems,
#  Engineering,
#  with,
#  minimum,
#  three,
#  years,
#  of,
#  experience,
#  in,
#  healthcare,
#  OR,
#  Master,
#  's,
#  degree,
#  with,
#  minimum,
#  two,
#  years,
#  of,
#  experience,
#  in,
#  healthcare,
#  .,
#  ,
#  Experience,
#  in,
#  the,
#  application,
#  of,
#  industrial,
#  and,
#  systems,
#  engineering,
#  /,
#  operations,
#  research,
#  tools,
#  and,
#  techniques,
#  in,
#  solving,
#  complex,
#  problems,
#  in,
#  healthcare,
#  .,
#  Demonstrated,
#  experience,
#  in,
#  projects,
#  related,
#  to,
#  operational,
#  assessments,
#  ,,
#  process,
#  redesign,
#  ,,
#  business,
#  transformation,
#  ,,
#  scheduling,
#  ,,
#  staffing,
#  ,,
#  resource,
#  allocation,
#  and,
#  process,
#  flow,
#  modeling,
#  and,
#  creating,
#  and,
#  executing,
#  robust,
#  measurement,
#  and,
#  impact,
#  evaluation,
#  plans,
#  .,
#  ,
#  KNOWLEDGE,
#  ,,
#  SKILLS,
#  ,,
#  AND,
#  ABILITIES,
#  REQUIRED,
#  :,
#
#  ,
#  Advanced,
#  knowledge,
#  and,
#  developing,
#  understanding,
#  of,
#  the,
#  application,
#  of,
#  core,
#  business,
#  consulting,
#  ,,
#  industrial,
#  and,
#  systems,
#  engineering,
#  processes,
#  ,,
#  methodologies,
#  ,,
#  and,
#  tools,
#  .,
#  ,
#  Expert,
#  knowledge,
#  of,
#  Lean,
#  ,,
#  Six,
#  Sigma,
#  ,,
#  PDSA,
#  ,,
#  Rapid,
#  Cycle,
#  Process,
#  Improvement,
#  ,,
#  or,
#  other,
#  management,
#  methods,
#  .,
#  ,
#  Advanced,
#  knowledge,
#  of,
#  quantitative,
#  modeling,
#  approaches,
#  ,,
#  such,
#  as,
#  Queuing,
#  ,,
#  Optimization,
#  ,,
#  and,
#  process,
#  modeling,
#  (,
#  example,
#  MedModel,
#  ,,
#  FlexSim,
#  ,,
#  Arena,
#  ,,
#  Simio,
#  ),
#  .,
#  ,
#  Strong,
#  analytical,
#  and,
#  critical,
#  thinking,
#  skills,
#  ,,
#  especially,
#  in,
#  workflow,
#  analyses,
#  and,
#  data,
#  analysis,
#  using,
#  statistical,
#  tools,
#  .,
#  ,
#  Advanced,
#  skills,
#  in,
#  Microsoft,
#  productivity,
#  tools,
#  with,
#  high,
#  level,
#  expertise,
#  in,
#  MS,
#  Excel,
#  and,
#  Visio,
#  .,
#  ,
#  Excellent,
#  organizational,
#  skills,
#  with,
#  a,
#  strong,
#  focus,
#  on,
#  details,
#  .,
#  ,
#  Demonstrated,
#  project,
#  management,
#  and,
#  stakeholder,
#  engagement,
#  skills,
#  ...]

# %%
filtered_tokens = [token for token in doc if not token.is_stop]
filtered_tokens
# Out:
# [Data,
#  Scientist,
#  ,
#  HomeInternational,
#  Saudi,
#  Arabia,
#  Eastern,
#  Province,
#  KhobarJobs,
#  ,
#  Date,
#  :,
#  Monday,
#  ,,
#  March,
#  01,
#  ,,
#  2021,
#  ,
#  Category,
#  :,
#  Jobs,
#  ,
#  Region,
#  Khobar,
#  ,
#  Posting,
#  ID,
#  :,
#  47603327,
#  ,
#  Job,
#  Duties,
#  /,
#  Responsibilities,
#  ,
#  •,
#  Ingest,
#  ,,
#  organize,
#  ,,
#  analyze,
#  data,
#  sources,
#  (,
#  e.g.,
#  CSV,
#  ,,
#  relational,
#  database,
#  ),
#  ,
#  •,
#  Scope,
#  unstructured,
#  problems,
#  messy,
#  data,
#  tractable,
#  insights,
#  ,
#  •,
#  Identify,
#  candidate,
#  statistical,
#  machine,
#  learning,
#  solutions,
#  test,
#  efficacy,
#  ,
#  •,
#  Communicate,
#  technical,
#  work,
#  findings,
#  verbally,
#  written,
#  reports,
#  visualizations,
#  ,
#  •,
#  Work,
#  collaborative,
#  environment,
#  brainstorm,
#  ,,
#  design,
#  ,,
#  implement,
#  deliver,
#  solutions,
#  challenging,
#  problems,
#  ,
#  Qualifications,
#  Skills,
#  ,
#  •,
#  3,
#  +,
#  years,
#  relevant,
#  data,
#  science,
#  work,
#  experience,
#  ,
#  •,
#  2,
#  +,
#  years,
#  relevant,
#  oil,
#  gas,
#  industry,
#  experience,
#  ,
#  •,
#  Excellent,
#  understanding,
#  statistical,
#  machine,
#  learning,
#  techniques,
#  ,,
#  clustering,
#  ,,
#  regression,
#  ,,
#  time,
#  series,
#  forecasting,
#  ,,
#  tree,
#  -,
#  based,
#  methods,
#  ,,
#  sampling,
#  methods,
#  ,
#  •,
#  Demonstrated,
#  ability,
#  scientific,
#  computing,
#  libraries,
#  ,,
#  NumPy,
#  ,,
#  Pandas,
#  ,,
#  SciPy,
#  ,,
#  Scikit,
#  -,
#  learn,
#  ,,
#  Matplotlib,
#  ,,
#  Plotly,
#  ,
#  •,
#  Programming,
#  proficiency,
#  Python,
#  ,
#  Preferred,
#  Requirements,
#  ,
#  •,
#  Ph.D.,
#  Master,
#  ,
#  •,
#  Petroleum,
#  Engineering,
#  Geoscience,
#  background,
#  ,
#  •,
#  Strong,
#  statistical,
#  knowledge,
#  experience,
#  hypothesis,
#  testing,
#  ,
#  •,
#  Fluency,
#  machine,
#  learning,
#  algorithms,
#  ,,
#  CNN,
#  ,,
#  RNN,
#  ,,
#  reinforcement,
#  learning,
#  ,,
#  support,
#  vector,
#  machines,
#  ,,
#  graph,
#  -,
#  based,
#  models,
#  ,
#  •,
#  Experience,
#  TensorFlow,
#  ,,
#  Keras,
#  ,,
#  PyTorch,
#  ,
#  •,
#  Experience,
#  version,
#  control,
#  systems,
#  (,
#  e.g.,
#  Git,
#  flow,
#  ),
#  ,
#  •,
#  Strong,
#  oral,
#  verbal,
#  communication,
#  skills,
#  ,
#  •,
#  Research,
#  experience,
#  high,
#  impact,
#  publications,
#  ,
#  •,
#  Experience,
#  working,
#  cross,
#  -,
#  functional,
#  teams,
#  and/or,
#  customer,
#  facing,
#  work,
#
#  ,
#  send,
#  CV,
#  cover,
#  letter,
#  HR@metelecom.net.sa,
#
#
#  ,
#  Dana,
#  -,
#  Farber,
#  Cancer,
#  Institute,
#  brings,
#  world,
#  -,
#  renowned,
#  clinicians,
#  ,,
#  innovative,
#  researchers,
#  ,,
#  dedicated,
#  professionals,
#  ,,
#  allies,
#  shared,
#  mission,
#  conquering,
#  cancer,
#  related,
#  diseases,
#  .,
#  combine,
#  incredibly,
#  talented,
#  people,
#  best,
#  technologies,
#  genuinely,
#  positive,
#  environment,
#  .,
#  provide,
#  compassionate,
#  comprehensive,
#  care,
#  patients,
#  ages,
#  ;,
#  conduct,
#  research,
#  advances,
#  treatment,
#  ;,
#  educate,
#  tomorrow,
#  physician,
#  /,
#  researchers,
#  ;,
#  reach,
#  underserved,
#  members,
#  community,
#  ;,
#  work,
#  excellent,
#  partners,
#  ,,
#  including,
#  Harvard,
#  Medical,
#  School,
#  -,
#  affiliated,
#  hospitals,
#  .,
#
#  ,
#  Health,
#  Systems,
#  Engineer,
#  II,
#  independently,
#  leads,
#  improvement,
#  projects,
#  moderate,
#  complex,
#  nature,
#  stakeholders,
#  Institute,
#  .,
#  position,
#  acts,
#  subject,
#  matter,
#  expert,
#  improvement,
#  tools,
#  techniques,
#  ,,
#  serves,
#  resource,
#  staff,
#  Institute,
#  creating,
#  reliable,
#  ,,
#  safe,
#  efficient,
#  processes,
#  ;,
#  Works,
#  closely,
#  team,
#  members,
#  ensure,
#  completion,
#  improvement,
#  initiatives,
#  defined,
#  budget,
#  schedule,
#  .,
#
#  ,
#  Requirements,
#
#  ,
#  PRIMARY,
#  DUTIES,
#  RESPONSIBILITIES,
#  :,
#
#  ,
#  Works,
#  member,
#  Health,
#  Systems,
#  Improvement,
#  team,
#  Quality,
#  Patient,
#  Safety,
#  department,
#  plan,
#  execute,
#  high,
#  priority,
#  initiatives,
#  stakeholders,
#  .,
#  Assists,
#  business,
#  strategy,
#  planning,
#  ,,
#  business,
#  process,
#  engineering,
#  business,
#  transformation,
#  initiatives,
#  .,
#  ,
#  Acts,
#  subject,
#  matter,
#  expert,
#  industrial,
#  systems,
#  engineering,
#  process,
#  improvement,
#  tools,
#  techniques,
#  .,
#  ,
#  Independently,
#  selects,
#  appropriate,
#  methods,
#  procedures,
#  assigned,
#  projects,
#  .,
#  ,
#  Responsible,
#  portfolio,
#  projects,
#  consist,
#  broad,
#  spectrum,
#  improvement,
#  initiatives,
#  different,
#  departments/,
#  disciplines,
#  ensuring,
#  project,
#  completed,
#  schedule,
#  budget,
#  ..,
#  ,
#  Independently,
#  ,,
#  performs,
#  data,
#  analysis,
#  ,,
#  develops,
#  findings,
#  recommendations,
#  .,
#  ,
#  Creates,
#  project,
#  presentations,
#  steering,
#  committees,
#  ,,
#  business,
#  leaders,
#  project,
#  sponsors,
#  .,
#  ,
#  Identifies,
#  ,,
#  translates,
#  applies,
#  best,
#  practices,
#  assigned,
#  projects,
#  .,
#  ,
#  Ensures,
#  communication,
#  business,
#  proponents,
#  ,,
#  stakeholders,
#  ,,
#  departmental,
#  leadership,
#  timely,
#  accurate,
#  .,
#  ,
#  Interacts,
#  frequently,
#  program,
#  leaders,
#  ,,
#  staff,
#  ,,
#  clinicians,
#  effectively,
#  implement,
#  improvement,
#  initiatives,
#  .,
#  ,
#  Coaches,
#  project,
#  stakeholders,
#  planning,
#  implementing,
#  effective,
#  workflow,
#  support,
#  related,
#  data,
#  capture,
#  strategies,
#  .,
#  ,
#  Creates,
#  project,
#  artifacts,
#  deliverables,
#  ,,
#  process,
#  flow,
#  maps,
#  ,,
#  data,
#  analysis,
#  ,,
#  models,
#  ,,
#  reports,
#  ,,
#  develop,
#  ,,
#  organize,
#  ,,
#  summarize,
#  materials,
#  presentations,
#  .,
#  ,
#  Provides,
#  project,
#  support,
#  senior,
#  members,
#  team,
#  .,
#  ,
#  collaboration,
#  Senior,
#  Director,
#  /,
#  Manager,
#  ,,
#  develops,
#  delivers,
#  curriculum,
#  staff,
#  improvement,
#  training,
#  programs,
#  .,
#  ,
#  Performs,
#  related,
#  duties,
#  required,
#  .,
#  ,
#  Qualifications,
#
#  ,
#  MINIMUM,
#  JOB,
#  QUALIFICATIONS,
#  :,
#
#  ,
#  Bachelor,
#  degree,
#  required,
#  formal,
#  training,
#  Industrial,
#  Systems,
#  Engineering,
#  minimum,
#  years,
#  experience,
#  healthcare,
#  Master,
#  degree,
#  minimum,
#  years,
#  experience,
#  healthcare,
#  .,
#  ,
#  Experience,
#  application,
#  industrial,
#  systems,
#  engineering,
#  /,
#  operations,
#  research,
#  tools,
#  techniques,
#  solving,
#  complex,
#  problems,
#  healthcare,
#  .,
#  Demonstrated,
#  experience,
#  projects,
#  related,
#  operational,
#  assessments,
#  ,,
#  process,
#  redesign,
#  ,,
#  business,
#  transformation,
#  ,,
#  scheduling,
#  ,,
#  staffing,
#  ,,
#  resource,
#  allocation,
#  process,
#  flow,
#  modeling,
#  creating,
#  executing,
#  robust,
#  measurement,
#  impact,
#  evaluation,
#  plans,
#  .,
#  ,
#  KNOWLEDGE,
#  ,,
#  SKILLS,
#  ,,
#  ABILITIES,
#  REQUIRED,
#  :,
#
#  ,
#  Advanced,
#  knowledge,
#  developing,
#  understanding,
#  application,
#  core,
#  business,
#  consulting,
#  ,,
#  industrial,
#  systems,
#  engineering,
#  processes,
#  ,,
#  methodologies,
#  ,,
#  tools,
#  .,
#  ,
#  Expert,
#  knowledge,
#  Lean,
#  ,,
#  Sigma,
#  ,,
#  PDSA,
#  ,,
#  Rapid,
#  Cycle,
#  Process,
#  Improvement,
#  ,,
#  management,
#  methods,
#  .,
#  ,
#  Advanced,
#  knowledge,
#  quantitative,
#  modeling,
#  approaches,
#  ,,
#  Queuing,
#  ,,
#  Optimization,
#  ,,
#  process,
#  modeling,
#  (,
#  example,
#  MedModel,
#  ,,
#  FlexSim,
#  ,,
#  Arena,
#  ,,
#  Simio,
#  ),
#  .,
#  ,
#  Strong,
#  analytical,
#  critical,
#  thinking,
#  skills,
#  ,,
#  especially,
#  workflow,
#  analyses,
#  data,
#  analysis,
#  statistical,
#  tools,
#  .,
#  ,
#  Advanced,
#  skills,
#  Microsoft,
#  productivity,
#  tools,
#  high,
#  level,
#  expertise,
#  MS,
#  Excel,
#  Visio,
#  .,
#  ,
#  Excellent,
#  organizational,
#  skills,
#  strong,
#  focus,
#  details,
#  .,
#  ,
#  Demonstrated,
#  project,
#  management,
#  stakeholder,
#  engagement,
#  skills,
#  .,
#  ,
#  Exceptional,
#  written,
#  oral,
#  communication,
#  abilities,
#  .,
#  ,
#  Ability,
#  work,
#  assignments,
#  difficult,
#  require,
#  judgment,
#  resolving,
#  issues,
#  making,
#  recommendations,
#  .,
#  ,
#  Ability,
#  work,
#  effectively,
#  technical,
#  ,,
#  clinical,
#  ,,
#  operational,
#  staff,
#  .,
#  ,
#  Skilled,
#  managing,
#  implementing,
#  change,
#  ,,
#  particularly,
#  quality,
#  improvement,
#  ,,
#  process,
#  improvement,
#  ,,
#  pay,
#  performance,
#  initiatives,
#  .,
#
#
#  ,
#  :,
#  arjun@eramtalent.com,
#  ,
#  Date,
#  :,
#  Tuesday,
#  ,,
#  June,
#  22,
#  ,,
#  2021,
#  ,
#  Category,
#  :,
#  Jobs,
#  ,
#  Region,
#  Riyadh,
#  ,
#  Posting,
#  ID,
#  :,
#  48318411,
#  ,
#  Position,
#  Description,
#  :,
#
#  ,
#  Hydrocarbon,
#  Management,
#  Division,
#  (,
#  HMD,
#  ),
#  dedicated,
#  development,
#  analytical,
#  applications,
#  serve,
#  Saudi,
#  Aramco,
#  organizations,
#  .,
#  analytical,
#  applications,
#  include,
#  traditional,
#  BI,
#  functionalities,
#  ,,
#  visualization,
#  &,
#  reporting,
#  ,,
#  advanced,
#  analytical,
#  tasks,
#  ,,
#  predictive,
#  analytics,
#  ,,
#  text,
#  analytics,
#  ,,
#  optimization,
#  .,
#  order,
#  serve,
#  mission,
#  HMD,
#  ,,
#  qualified,
#  data,
#  scientists,
#  needed,
#  develop,
#  implement,
#  solutions,
#  wide,
#  range,
#  domains,
#  .,
#
#  ,
#  job,
#  roles,
#  :,
#  ,
#  1,
#  .,
#  Participate,
#  implementation,
#  advanced,
#  analytical,
#  applications,
#  Hydrocarbon,
#  Management,
#  Division,
#  (,
#  HMD,
#  ),
#  .,
#  ,
#  2,
#  .,
#  Develop,
#  ,,
#  evaluate,
#  deploy,
#  machine,
#  learning,
#  models,
#  IBM,
#  Cloud,
#  Pak,
#  Data,
#  ,
#  3,
#  .,
#  Develop,
#  ,,
#  enhance,
#  test,
#  applications,
#  based,
#  Hadoop,
#  /,
#  Spark,
#  ,,
#  Splunk,
#  ,,
#  SAP,
#  HANA,
#  ,,
#  SAP,
#  BO,
#  ,,
#  Microsoft,
#  R,
#  Server,
#  ,,
#  Microsoft,
#  Power,
#  BI,
#  .,
#  ,
#  4,
#  .,
#  Develop,
#  ,,
#  evaluate,
#  deploy,
#  machine,
#  learning,
#  models,
#  open,
#  sources,
#  packages,
#  Python,
#  R.,
#  ,
#  5,
#  .,
#  Develop,
#  necessary,
#  documentation,
#  established,
#  standards,
#  .,
#  ,
#  6,
#  .,
#  Review,
#  analyze,
#  user,
#  requests,
#  advanced,
#  analytics,
#  document,
#  end,
#  user,
#  requirements,
#  .,
#  ,
#  ...]
