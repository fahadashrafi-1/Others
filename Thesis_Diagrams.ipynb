# %%
from IPython.display import Image

import os
os.environ["PATH"] += os.pathsep + 'C:/Program Files (x86)/Graphviz/bin'
# Image('digraph.png')
from graphviz import Digraph
# Create Digraph object
dot = Digraph()

# %%
dot.node('1', 'Emerging Technologies')
dot.node('2', 'ERP System Benefits')
dot.node('3', 'ERP Usefulness')
dot.node('4', 'Economic Benefits')

# %%
dot.edges(['12','23', '34'])

# %%
dot
